# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/Car_Purchasing_Data.csv')

# %%
df
# Out:
#        Customer Name                                    Customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           Country  Gender        Age  Annual Salary  Credit Card Debt  \
# 0        Bulgaria       0  41.851720    62812.09301      11609.380910
# 1          Belize       0  40.870623    66646.89292       9572.957136
# 2         Algeria       1  43.152897    53798.55112      11160.355060
# 3    Cook Islands       1  58.271369    79370.03798      14426.164850
# 4          Brazil       1  57.313749    59729.15130       5358.712177
# ..            ...     ...        ...            ...               ...
# 495         Nepal       0  41.462515    71942.40291       6995.902524
# 496      Zimbabwe       1  37.642000    56039.49793      12301.456790
# 497   Philippines       1  53.943497    68888.77805      10611.606860
# 498      Botswana       1  59.160509    49811.99062      14013.034510
# 499        marlal       1  46.731152    61370.67766       9391.341628
#
#        Net Worth  Car Purchase Amount
# 0    238961.2505          35321.45877
# 1    530973.9078          45115.52566
# 2    638467.1773          42925.70921
# 3    548599.0524          67422.36313
# 4    560304.0671          55915.46248
# ..           ...                  ...
# 495  541670.1016          48901.44342
# 496  360419.0988          31491.41457
# 497  764531.3203          64147.28888
# 498  337826.6382          45442.15353
# 499  462946.4924          45107.22566
#
# [500 rows x 9 columns]

# %%
df.describe()
# Out:
#            Gender         Age  Annual Salary  Credit Card Debt  \
# count  500.000000  500.000000     500.000000        500.000000
# mean     0.506000   46.241674   62127.239608       9607.645049
# std      0.500465    7.978862   11703.378228       3489.187973
# min      0.000000   20.000000   20000.000000        100.000000
# 25%      0.000000   40.949969   54391.977195       7397.515792
# 50%      1.000000   46.049901   62915.497035       9655.035568
# 75%      1.000000   51.612263   70117.862005      11798.867487
# max      1.000000   70.000000  100000.000000      20000.000000
#
#             Net Worth  Car Purchase Amount
# count      500.000000           500.000000
# mean    431475.713625         44209.799218
# std     173536.756340         10773.178744
# min      20000.000000          9000.000000
# 25%     299824.195900         37629.896040
# 50%     426750.120650         43997.783390
# 75%     557324.478725         51254.709517
# max    1000000.000000         80000.000000

# %%
# 연봉이 가장 높은 사람??
df.loc[df['Annual Salary']== df['Annual Salary'].max(), ]
# Out:
#     Customer Name     Customer e-mail  Country  Gender        Age  \
# 28  Gemma Hendrix  lobortis@non.co.uk  Denmark       1  46.124036
#
#     Annual Salary  Credit Card Debt    Net Worth  Car Purchase Amount
# 28       100000.0       17452.92179  188032.0778          58350.31809

# %%
# 카드 값이 많은 사람??
df.loc[df['Credit Card Debt']== df['Credit Card Debt'].max(), ]
# Out:
#       Customer Name                        Customer e-mail  Country  Gender  \
# 221  Laurel H. Snow  dui.Suspendisse.ac@tacitisociosqu.org  Andorra       1
#
#            Age  Annual Salary  Credit Card Debt    Net Worth  \
# 221  36.408033    69494.69783           20000.0  335809.6171
#
#      Car Purchase Amount
# 221          37303.56701

# %%
df_corr = df.corr(numeric_only=True)

# %%
import seaborn as sb

# %%
sb.heatmap(df_corr, annot=True, vmin= -1, vmax= 1, cmap='coolwarm', linewidths=0.5)
plt.show()

# %%
# 구매 금액 예측하는 인공지능 개발

# %%
df.isna().sum()
# Out:
# Customer Name          0
# Customer e-mail        0
# Country                0
# Gender                 0
# Age                    0
# Annual Salary          0
# Credit Card Debt       0
# Net Worth              0
# Car Purchase Amount    0
# dtype: int64

# %%
df.head(2)
# Out:
#    Customer Name                                    Customer e-mail   Country  \
# 0  Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu  Bulgaria
# 1  Harlan Barnes                                eu.dolor@diam.co.uk    Belize
#
#    Gender        Age  Annual Salary  Credit Card Debt    Net Worth  \
# 0       0  41.851720    62812.09301      11609.380910  238961.2505
# 1       0  40.870623    66646.89292       9572.957136  530973.9078
#
#    Car Purchase Amount
# 0          35321.45877
# 1          45115.52566

# %%
df.shape
# Out:
# (500, 9)

# %%
df['Country'].nunique()
# Out:
# 211

# %%
df['Country'].value_counts()
# Out:
# Country
# Israel                 6
# Mauritania             6
# Bolivia                6
# Greenland              5
# Saint Barth?emy        5
#                       ..
# El Salvador            1
# Denmark                1
# Oman                   1
# Trinidad and Tobago    1
# marlal                 1
# Name: count, Length: 211, dtype: int64

# %%
sb.countplot(data=df, x='Country')
plt.show()
# Out:
# c:\Users\USER\anaconda3\envs\hi\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 55112 (\N{HANGUL SYLLABLE HYUSS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.head(2)
# Out:
#    Customer Name                                    Customer e-mail   Country  \
# 0  Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu  Bulgaria
# 1  Harlan Barnes                                eu.dolor@diam.co.uk    Belize
#
#    Gender        Age  Annual Salary  Credit Card Debt    Net Worth  \
# 0       0  41.851720    62812.09301      11609.380910  238961.2505
# 1       0  40.870623    66646.89292       9572.957136  530973.9078
#
#    Car Purchase Amount
# 0          35321.45877
# 1          45115.52566

# %%
y = df['Car Purchase Amount']

# %%
X = df.loc[ : , 'Age' : 'Net Worth' ]

# %%
X
# Out:
#            Age  Annual Salary  Credit Card Debt    Net Worth
# 0    41.851720    62812.09301      11609.380910  238961.2505
# 1    40.870623    66646.89292       9572.957136  530973.9078
# 2    43.152897    53798.55112      11160.355060  638467.1773
# 3    58.271369    79370.03798      14426.164850  548599.0524
# 4    57.313749    59729.15130       5358.712177  560304.0671
# ..         ...            ...               ...          ...
# 495  41.462515    71942.40291       6995.902524  541670.1016
# 496  37.642000    56039.49793      12301.456790  360419.0988
# 497  53.943497    68888.77805      10611.606860  764531.3203
# 498  59.160509    49811.99062      14013.034510  337826.6382
# 499  46.731152    61370.67766       9391.341628  462946.4924
#
# [500 rows x 4 columns]

# %%
y
# Out:
# 0      35321.45877
# 1      45115.52566
# 2      42925.70921
# 3      67422.36313
# 4      55915.46248
#           ...
# 495    48901.44342
# 496    31491.41457
# 497    64147.28888
# 498    45442.15353
# 499    45107.22566
# Name: Car Purchase Amount, Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=3)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
regressor1 = LinearRegression()

# %%
regressor1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
# %%
mean_squared_error(y_test, y_pred)
# Out:
# 2.454717476532372

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9999999783631199

# %%
df_y = y_test.to_frame()

# %%
df_y
# Out:
#      Car Purchase Amount
# 130          51551.67997
# 291          53848.75550
# 37           10092.22509
# 239          44434.98419
# 191          42774.35579
# ..                   ...
# 367          46710.52519
# 302          44463.30502
# 175          49050.85378
# 348          49348.88394
# 356          38042.80065
#
# [100 rows x 1 columns]

# %%
df_y['y_pred'] = y_pred

# %%
df_y
# Out:
#      Car Purchase Amount        y_pred
# 130          51551.67997  51552.278235
# 291          53848.75550  53849.001284
# 37           10092.22509  10091.731081
# 239          44434.98419  44437.166354
# 191          42774.35579  42774.332398
# ..                   ...           ...
# 367          46710.52519  46714.207457
# 302          44463.30502  44463.931120
# 175          49050.85378  49049.847022
# 348          49348.88394  49345.636955
# 356          38042.80065  38042.945339
#
# [100 rows x 2 columns]

# %%
# 차트 그리기

# %%
df_y.reset_index(drop=True, inplace=True)

# %%
df_y.head()
# Out:
#    Car Purchase Amount        y_pred
# 0          51551.67997  51552.278235
# 1          53848.75550  53849.001284
# 2          10092.22509  10091.731081
# 3          44434.98419  44437.166354
# 4          42774.35579  42774.332398

# %%
df_y.loc[0:19, : ].plot(kind='bar')
plt.show()

# %%
regressor2 = RandomForestRegressor(random_state=3)

# %%
regressor2.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=3)

# %%
y_pred2 = regressor2.predict(X_test)

# %%
y_pred2
# Out:
# array([53418.7762271, 52728.8592905, 18183.5826547, 44591.8822032,
#        43231.5778975, 59293.8030789, 24057.3270311, 49471.0899079,
#        47514.8186506, 54681.9878975, 40487.687209 , 32019.6809623,
#        46109.9170489, 51361.2184257, 30466.4533561, 32480.2212663,
#        47976.049077 , 35716.0768755, 54251.3457465, 48629.0109503,
#        40975.2700819, 63577.0889583, 41255.1038445, 40346.8604074,
#        45604.5551783, 40629.8899387, 46395.7124599, 44118.1440888,
#        54360.283316 , 52878.4123257, 36342.803434 , 51736.8362913,
#        22697.3163267, 49118.7622488, 49424.7827554, 34975.2578695,
#        38199.6821   , 50614.9854132, 39683.3634595, 41393.631968 ,
#        34241.2718534, 36861.8968418, 43720.7036032, 62053.4380172,
#        64551.5205749, 53485.3564847, 47602.1763603, 46677.3798129,
#        47774.0436391, 41513.3179577, 43538.8361663, 58756.559002 ,
#        47073.2770719, 39925.9643025, 57443.2324074, 33206.9443026,
#        32764.5457308, 50874.2168155, 52824.5801579, 37395.970419 ,
#        42167.1862584, 50624.4293221, 46154.1258147, 50999.5282069,
#        60373.9221316, 43134.7583184, 44276.3460131, 27818.8068303,
#        43778.1218247, 31019.1148224, 44449.1429495, 47845.2267226,
#        55250.4102282, 47375.4582523, 35952.5569208, 41121.5493638,
#        38119.8619465, 24322.9343922, 50915.2572908, 53063.8665041,
#        52675.54524  , 35928.4262574, 41578.1948934, 33390.0053098,
#        48187.6983805, 43659.5314131, 44589.8253356, 37985.8079247,
#        27716.0997572, 60468.7572823, 57518.2833418, 44175.1900382,
#        53814.0226984, 39840.8145556, 27249.3409628, 44905.6427456,
#        44139.3430751, 48310.7891341, 48088.3738429, 36835.5809452])

# %%
mean_squared_error(y_test, y_pred2)
# Out:
# 6269249.030551822

# %%
r2_score(y_test, y_pred2)
# Out:
# 0.9447402844580766

# %%
# 신규 고객에게 얼마나 팔 수 있을지 예측
# 40세, 50000 연봉, 10000 카드 빚, 600000 순자산

# %%
import numpy as np

# %%
new_data = np.array( [40, 50000, 10000, 600000] )

# %%
new_data = new_data.reshape(1, 4)

# %%
regressor1.predict(new_data)
# Out:
# c:\Users\USER\anaconda3\envs\hi\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([37021.92477431])

# %%
import joblib

# %%
joblib.dump(regressor1, 'model/regressor.pkl')
# Out:
# ['model/regressor.pkl']
